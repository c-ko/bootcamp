# %% [markdown]
# # Exercise 5.1

# %%
# !head -20 data/frog_tongue_adhesion.csv
# Out:
# # These data are from the paper,
# #   Kleinteich and Gorb, Sci. Rep., 4, 5225, 2014.
# # It was featured in the New York Times.
# #    http://www.nytimes.com/2014/08/25/science/a-frog-thats-a-living-breathing-pac-man.html
# #
# # The authors included the data in their supplemental information.
# #
# # Importantly, the ID refers to the identifites of the frogs they tested.
# #   I:   adult, 63 mm snout-vent-length (SVL) and 63.1 g body weight,
# #        Ceratophrys cranwelli crossed with Ceratophrys cornuta
# #   II:  adult, 70 mm SVL and 72.7 g body weight,
# #        Ceratophrys cranwelli crossed with Ceratophrys cornuta
# #   III: juvenile, 28 mm SVL and 12.7 g body weight, Ceratophrys cranwelli
# #   IV:  juvenile, 31 mm SVL and 12.7 g body weight, Ceratophrys cranwelli
# ...

# %%
df = pd.read_csv('data/frog_tongue_adhesion.csv', comment='#')

# %%
df
# Out:
#           date   ID  trial number  impact force (mN)  impact time (ms)  \
# 0   2013_02_26    I             3               1205                46
# 1   2013_02_26    I             4               2527                44
# 2   2013_03_01    I             1               1745                34
# 3   2013_03_01    I             2               1556                41
# 4   2013_03_01    I             3                493                36
# 5   2013_03_01    I             4               2276                31
# 6   2013_03_05    I             1                556                43
# 7   2013_03_05    I             2               1928                46
# 8   2013_03_05    I             3               2641                50
# 9   2013_03_05    I             4               1897                41
# 10  2013_03_12    I             1               1891                40
# 11  2013_03_12    I             2               1545                48
# ...

# %%
df.loc[np.abs(df['adhesive strength (Pa)'])>2000]
# Out:
#           date   ID  trial number  impact force (mN)  impact time (ms)  \
# 0   2013_02_26    I             3               1205                46
# 1   2013_02_26    I             4               2527                44
# 2   2013_03_01    I             1               1745                34
# 4   2013_03_01    I             3                493                36
# 7   2013_03_05    I             2               1928                46
# 8   2013_03_05    I             3               2641                50
# 11  2013_03_12    I             2               1545                48
# 13  2013_03_12    I             4               1692                31
# 14  2013_03_12    I             5               1543                38
# 17  2013_03_15    I             3               2032                60
# 19  2013_03_15    I             5                473                40
# 23  2013_03_19   II             4                946                59
# ...

# %%
inds = (df['ID']=='II')
df.loc[inds, ['impact force (mN)','adhesive force (mN)']] 
# use lists if you want to do more than one thing
# Out:
#     impact force (mN)  adhesive force (mN)
# 20               1612                 -655
# 21                605                 -292
# 22                327                 -246
# 23                946                 -245
# 24                541                 -553
# 25               1539                 -664
# 26                529                 -261
# 27                628                 -691
# 28               1453                  -92
# 29                297                 -566
# 30                703                 -223
# 31                269                 -512
# 32                751                 -227
# 33                245                 -573
# 34               1182                 -522
# 35                515                 -599
# 36                435                 -364
# 37                383                 -469
# 38                457                 -844
# 39                730                 -648

# %%
inds = (df['ID'].isin(['III', 'IV'])) #is in and put in a list
df.loc[inds, ['time frog pulls on target (ms)','adhesive force (mN)']] 
# use lists if you want to do more than one thing
# Out:
#     time frog pulls on target (ms)  adhesive force (mN)
# 40                             683                  -94
# 41                             245                 -163
# 42                             619                 -172
# 43                            1823                 -225
# 44                             918                 -301
# 45                            1351                  -93
# 46                            1790                 -131
# 47                            1006                 -289
# 48                             883                 -104
# 49                            1218                 -229
# 50                             910                 -259
# 51                             550                 -231
# 52                            2081                 -267
# 53                             376                 -178
# 54                             289                 -123
# 55                             607                 -151
# ...

# %%
seq = 'GCTACAG'

# %%
def complement_base(base, material = 'DNA'): #defining default value 
    """Return the Watson-Crick complement of a base."""
    if base in 'Aa':
        if material == 'DNA':
            return 'T'
        if material == 'RNA':
            return 'U'
    elif base in 'Tt':
        return 'A'
    elif base in 'Gg':
        return 'C'
    else:
        return 'G'


#named keyword argument 
def reverse_complement(seq, material = 'DNA'):
    """Compute reverse complement of a nuclei acid sequence."""
    # Initialize the reverse complement
    rev_seq=''
    #loop through and add on appropriate bases
    for i,_ in enumerate(seq):
        index=len(seq)-1-i
        rev_seq+=complement_base(seq[index],material = material)
    return rev_seq

# %%
reverse_complement(seq)
# Out:
# 'CTGTAGC'

# %%
def reverse_complement(seq, material = 'DNA'):
    """Compute reverse complement of a nuclei acid sequence."""
    # Initialize the reverse complement
    rev_seq=''
    #loop through and add on appropriate bases
    for i,_ in enumerate(seq):
        index=len(seq)-1-i
        rev_seq+=complement_base(seq[index],material = material)
    return rev_seq

# %% [markdown]
# # Exercise 3.1 The Twelve Days of Christmas

# %%
i=0
j=0

days = 12
for i in range(1,days + 1):
    j+=i
    print('day',i)
    print(j)
# Out:
# day 1
# 1
# day 2
# 3
# day 3
# 6
# day 4
# 10
# day 5
# 15
# day 6
# 21
# day 7
# 28
# day 8
# 36
# day 9
# 45
# day 10
# 55
# day 11
# 66
# day 12
# 78

# %%
print('Gifts received by Day ' + str(days) + ' is '+str(j))
# Out:
# Gifts received by Day 12 is 78

# %%
for day in range(1,days+1):
    gifts_for_day=(day*(day+1))//2
    print('Day', day, 'Gifts', gifts_for_day)
# Out:
# Day 1 Gifts 1
# Day 2 Gifts 3
# Day 3 Gifts 6
# Day 4 Gifts 10
# Day 5 Gifts 15
# Day 6 Gifts 21
# Day 7 Gifts 28
# Day 8 Gifts 36
# Day 9 Gifts 45
# Day 10 Gifts 55
# Day 11 Gifts 66
# Day 12 Gifts 78

# %% [markdown]
# # Exercise 1.3 Time and type conversions

# %%
seconds_past_midnight = 63252

# %%
7//3
# Out:
# 2

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7%3
# Out:
# 1

# %%
seconds_past_midnight/60
# Out:
# 1054.2

# %%
minutes_past_midnight=seconds_past_midnight//60
minutes_past_midnight
# Out:
# 1054

# %%
leftover_secs=seconds_past_midnight%60
leftover_secs
# Out:
# 12

# %%
hours_past_midnight=minutes_past_midnight//60
hours_past_midnight
# Out:
# 17

# %%
leftover_mins=minutes_past_midnight%60

# %%
leftover_mins
# Out:
# 34

# %%
print(str(hours_past_midnight)+':'+str(leftover_mins)+':'+str(leftover_secs))
# Out:
# 17:34:12
