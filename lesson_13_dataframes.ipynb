# %%
import numpy as np
import pandas as pd

# %%
# !head data/gfmt_sleep.csv 

df = pd.read_csv('data/gfmt_sleep.csv', na_values='*')

type(df)
# Out:
# ﻿participant number,gender,age,correct hit percentage,correct reject percentage,percent correct,confidence when correct hit,confidence when incorrect hit,confidence when correct reject,confidence when incorrect reject,confidence when correct,confidence when incorrect,sci,psqi,ess
# 8,f,39,65,80,72.5,91,90,93,83.5,93,90,9,13,2
# 16,m,42,90,90,90,75.5,55.5,70.5,50,75,50,4,11,7
# 18,f,31,90,95,92.5,89.5,90,86,81,89,88,10,9,3
# 22,f,35,100,75,87.5,89.5,*,71,80,88,80,13,8,20
# 27,f,74,60,65,62.5,68.5,49,61,49,65,49,13,9,12
# 28,f,61,80,20,50,71,63,31,72.5,64.5,70.5,15,14,2
# 30,m,32,90,75,82.5,67,56.5,66,65,66,64,16,9,3
# 33,m,62,45,90,67.5,54,37,65,81.5,62,61,14,9,9
# 34,f,33,80,100,90,70.5,76.5,64.5,*,68,76.5,14,12,10
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence when incorrect hit  confidence when correct reject  \
# 0                           90.0                            93.0
# ...

# %%
# Index by column
df['percent correct'][4]
# Out:
# 62.5

# %%
# Index by row index followed by column index
#.loc means index by row and then by column
df.loc[4, 'percent correct']
# Out:
# 62.5

# %%
df['participant number'] == 8
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: participant number, Length: 102, dtype: bool

# %%
df.loc[df['participant number'] == 8, 'percent correct']
# Out:
# 0    72.5
# Name: percent correct, dtype: float64

# %%
df.loc[(df['participant number'] == 8), :]
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
#
#    confidence when incorrect hit  confidence when correct reject  \
# 0                           90.0                            93.0
#
#    confidence when incorrect reject  confidence when correct  \
# 0                              83.5                     93.0
#
#    confidence when incorrect  sci  psqi  ess
# 0                       90.0    9    13    2

# %%
# All women under 21

df.loc[(df['age']<21) & (df['gender'] == 'f'), :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#     confidence when incorrect hit  confidence when correct reject  \
# 27                           57.0                            54.0
# ...

# %%
inds = (df['age']<30) & (df['gender'] == 'f') & (df['percent correct']>99)
df.loc[inds ,:]
# Out:
#     participant number gender  age  correct hit percentage  \
# 33                  10      f   25                     100
# 75                  67      f   25                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 33                        100            100.0                         90.0
# 75                        100            100.0                         61.5
#
#     confidence when incorrect hit  confidence when correct reject  \
# 33                            NaN                            85.0
# 75                            NaN                            58.5
#
#     confidence when incorrect reject  confidence when correct  \
# 33                               NaN                     90.0
# 75                               NaN                     60.5
#
#     confidence when incorrect  sci  psqi  ess
# 33                        NaN   17    10   11
# 75                        NaN   28     8    9

# %%
df['insomnia'] = df['sci'] <= 16 #make a new column in the dataframe and population it whenver sci <= 16

# %%
np.mean(df.loc[df['insomnia'], 'percent correct'])
# Out:
# 76.1

# %%
np.mean(df.loc[~df['insomnia'], 'percent correct'])
# Out:
# 81.46103896103897

# %%
df.describe()
# Out:
#        participant number         age  correct hit percentage  \
# count          102.000000  102.000000              102.000000
# mean            52.049020   37.921569               83.088235
# std             30.020909   14.029450               15.091210
# min              1.000000   16.000000               35.000000
# 25%             26.250000   26.500000               75.000000
# 50%             52.500000   36.500000               90.000000
# 75%             77.750000   45.000000               95.000000
# max            103.000000   74.000000              100.000000
#
#        correct reject percentage  percent correct  \
# count                 102.000000       102.000000
# mean                   77.205882        80.147059
# std                    17.569854        12.047881
# min                    20.000000        40.000000
# 25%                    70.000000        72.500000
# 50%                    80.000000        83.750000
# 75%                    90.000000        87.500000
# ...

# %%
df.to_csv("gfmt_sleep_with_insomnia.csv", index=False)

# %%
# !head -20 data/frog_tongue_adhesion.csv
# Out:
# # These data are from the paper,
# #   Kleinteich and Gorb, Sci. Rep., 4, 5225, 2014.
# # It was featured in the New York Times.
# #    http://www.nytimes.com/2014/08/25/science/a-frog-thats-a-living-breathing-pac-man.html
# #
# # The authors included the data in their supplemental information.
# #
# # Importantly, the ID refers to the identifites of the frogs they tested.
# #   I:   adult, 63 mm snout-vent-length (SVL) and 63.1 g body weight,
# #        Ceratophrys cranwelli crossed with Ceratophrys cornuta
# #   II:  adult, 70 mm SVL and 72.7 g body weight,
# #        Ceratophrys cranwelli crossed with Ceratophrys cornuta
# #   III: juvenile, 28 mm SVL and 12.7 g body weight, Ceratophrys cranwelli
# #   IV:  juvenile, 31 mm SVL and 12.7 g body weight, Ceratophrys cranwelli
# ...

# %%
df = pd.read_csv('data/frog_tongue_adhesion.csv', comment='#')

# %%
df
# Out:
#           date   ID  trial number  impact force (mN)  impact time (ms)  \
# 0   2013_02_26    I             3               1205                46
# 1   2013_02_26    I             4               2527                44
# 2   2013_03_01    I             1               1745                34
# 3   2013_03_01    I             2               1556                41
# 4   2013_03_01    I             3                493                36
# 5   2013_03_01    I             4               2276                31
# 6   2013_03_05    I             1                556                43
# 7   2013_03_05    I             2               1928                46
# 8   2013_03_05    I             3               2641                50
# 9   2013_03_05    I             4               1897                41
# 10  2013_03_12    I             1               1891                40
# 11  2013_03_12    I             2               1545                48
# ...

# %%
df.loc[np.abs(df['adhesive strength (Pa)'])>2000]
# Out:
#           date   ID  trial number  impact force (mN)  impact time (ms)  \
# 0   2013_02_26    I             3               1205                46
# 1   2013_02_26    I             4               2527                44
# 2   2013_03_01    I             1               1745                34
# 4   2013_03_01    I             3                493                36
# 7   2013_03_05    I             2               1928                46
# 8   2013_03_05    I             3               2641                50
# 11  2013_03_12    I             2               1545                48
# 13  2013_03_12    I             4               1692                31
# 14  2013_03_12    I             5               1543                38
# 17  2013_03_15    I             3               2032                60
# 19  2013_03_15    I             5                473                40
# 23  2013_03_19   II             4                946                59
# ...

# %%
inds = (df['ID']=='II')
df.loc[inds, ['impact force (mN)','adhesive force (mN)']] 
# use lists if you want to do more than one thing
# Out:
#     impact force (mN)  adhesive force (mN)
# 20               1612                 -655
# 21                605                 -292
# 22                327                 -246
# 23                946                 -245
# 24                541                 -553
# 25               1539                 -664
# 26                529                 -261
# 27                628                 -691
# 28               1453                  -92
# 29                297                 -566
# 30                703                 -223
# 31                269                 -512
# 32                751                 -227
# 33                245                 -573
# 34               1182                 -522
# 35                515                 -599
# 36                435                 -364
# 37                383                 -469
# 38                457                 -844
# 39                730                 -648

# %%
inds = (df['ID'].isin(['III', 'IV'])) #is in and put in a list
df.loc[inds, ['time frog pulls on target (ms)','adhesive force (mN)']] 
# use lists if you want to do more than one thing
# Out:
#     time frog pulls on target (ms)  adhesive force (mN)
# 40                             683                  -94
# 41                             245                 -163
# 42                             619                 -172
# 43                            1823                 -225
# 44                             918                 -301
# 45                            1351                  -93
# 46                            1790                 -131
# 47                            1006                 -289
# 48                             883                 -104
# 49                            1218                 -229
# 50                             910                 -259
# 51                             550                 -231
# 52                            2081                 -267
# 53                             376                 -178
# 54                             289                 -123
# 55                             607                 -151
# ...
